# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# Opción header: None para ignorar columnas automáticas
# Opición sep: "", para establecer delimintadores
# Opción nrows = N para leer únicamente N filas
dframe = pd.read_csv("/home/paul/Repositorios/Porsche/Concierge/Menu/Menu.csv")

# %%
# Método to_csv ára exporta csv
# Argumento sep = "" para establecer delimitadores
# Argumento columns = [] para exportar columnas seleccionadas
dframe.to_csv("exportar.csv")

# %%
import sys
dframe.to_csv(sys.stdout)
# Out:
# ,Año,Mes,Modelo,Nombre,Concesionaria,Sugerencias,Origen,Servicio,Unnamed: 8
# 0,2013,Ene,CAYENNE ,Miguel Angel Gonzalez,Porsche Centre Cancun,"Sean mas flexibles con las citas, que nos den opciones de traslado, yo voy de playa del carmen como 60 kms hasta el concesionario, que dieran opciones como VW, ellos me ofrecen pagar el traslado, o me prestan un auto.",Servicio,Traslado del auto,
# 1,2013,May,CAYMAN S,OSCAR ORTIZ VELAZQUEZ..,Porsche Centre San Angel,"lo que si les pudiera sugerir es que manejar promociones, algún programa de lealtad para los cliente que ya tenemos mas de 5 años con nuestro porsche. ",Servicio,Eventos,
# 2,2013,Jul,PORSCHE PANAMERA S,MANUEL MUÑOZ..,Porsche Centre San Angel,La verdad ojala y que un día pudieran pasar a la casa u oficina de uno por el auto o que pudieran ofrecer algún modo de transporte porque tiene uno que llevar un auto atrás de uno o tomar un taxi para regresar a la casa,Servicio,Traslado del auto,
# ...
