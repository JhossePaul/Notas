# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = "http://en.wikipedia.com/wiki/NFL_win-loss_records"
webbrowser.open(webs
                ite)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                Team   Won   Lost   Tied*   Pct.   First Season   \
# 0      1     Dallas Cowboys    510    378       6  0.574           1960
# 1      2      Chicago Bears    752    563      42  0.570           1920
# 2      3  Green Bay Packers    741    561      37  0.567           1921
# 3      4     Miami Dolphins    443    345       4  0.562           1966
# 4      5   Baltimore Ravens    182    143       1  0.560           1996
#
#    Total Games  Conference
# 0           894   NFC East
# 1          1357  NFC North
# 2          1339  NFC North
# 3           792   AFC East
# 4           326  AFC North

# %%
nfl_frame.columns
# Out:
# Index([u'Rank ', u'Team ', u'Won ', u'Lost ', u'Tied* ', u'Pct. ', u'First Season ', u'Total Games ', u'Conference'], dtype='object')

# %%
# notar la importancia del espacio
nfl_frame["Rank "]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank , dtype: int64

# %%
DataFrame(nfl_frame, columns = ["Team ", "First Season ", "Total Games "])
# Out:
#                 Team   First Season   Total Games
# 0     Dallas Cowboys            1960           894
# 1      Chicago Bears            1920          1357
# 2  Green Bay Packers            1921          1339
# 3     Miami Dolphins            1966           792
# 4   Baltimore Ravens            1996           326

# %%
DataFrame(nfl_frame, columns = ["Team ", "First Season ", "Total Games ", "Stadium"])
# Out:
#                 Team   First Season   Total Games   Stadium
# 0     Dallas Cowboys            1960           894      NaN
# 1      Chicago Bears            1920          1357      NaN
# 2  Green Bay Packers            1921          1339      NaN
# 3     Miami Dolphins            1966           792      NaN
# 4   Baltimore Ravens            1996           326      NaN

# %%
nfl_frame.head(3)
# Out:
#    Rank                Team   Won   Lost   Tied*   Pct.   First Season   \
# 0      1     Dallas Cowboys    510    378       6  0.574           1960
# 1      2      Chicago Bears    752    563      42  0.570           1920
# 2      3  Green Bay Packers    741    561      37  0.567           1921
#
#    Total Games  Conference
# 0           894   NFC East
# 1          1357  NFC North
# 2          1339  NFC North

# %%
nfl_frame.tail(1)
# Out:
#    Rank               Team   Won   Lost   Tied*   Pct.   First Season   \
# 4      5  Baltimore Ravens    182    143       1   0.56           1996
#
#    Total Games  Conference
# 4           326  AFC North

# %%
nfl_frame.ix[3]
# Out:
# Rank                           4
# Team             Miami Dolphins
# Won                          443
# Lost                         345
# Tied*                          4
# Pct.                       0.562
# First Season                1966
# Total Games                  792
# Conference              AFC East
# Name: 3, dtype: object

# %%
nfl_frame["Stadium"] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                Team   Won   Lost   Tied*   Pct.   First Season   \
# 0      1     Dallas Cowboys    510    378       6  0.574           1960
# 1      2      Chicago Bears    752    563      42  0.570           1920
# 2      3  Green Bay Packers    741    561      37  0.567           1921
# 3      4     Miami Dolphins    443    345       4  0.562           1966
# 4      5   Baltimore Ravens    182    143       1  0.560           1996
#
#    Total Games  Conference         Stadium
# 0           894   NFC East  Levi's Stadium
# 1          1357  NFC North  Levi's Stadium
# 2          1339  NFC North  Levi's Stadium
# 3           792   AFC East  Levi's Stadium
# 4           326  AFC North  Levi's Stadium

# %%
nfl_frame["Stadium"] = np.arange(5) + 1

# %%
nfl_frame
# Out:
#    Rank                Team   Won   Lost   Tied*   Pct.   First Season   \
# 0      1     Dallas Cowboys    510    378       6  0.574           1960
# 1      2      Chicago Bears    752    563      42  0.570           1920
# 2      3  Green Bay Packers    741    561      37  0.567           1921
# 3      4     Miami Dolphins    443    345       4  0.562           1966
# 4      5   Baltimore Ravens    182    143       1  0.560           1996
#
#    Total Games  Conference  Stadium
# 0           894   NFC East        1
# 1          1357  NFC North        2
# 2          1339  NFC North        3
# 3           792   AFC East        4
# 4           326  AFC North        5

# %%
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index = [4, 0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame["Stadium"] = stadiums

# %%
nfl_frame
# Out:
#    Rank                Team   Won   Lost   Tied*   Pct.   First Season   \
# 0      1     Dallas Cowboys    510    378       6  0.574           1960
# 1      2      Chicago Bears    752    563      42  0.570           1920
# 2      3  Green Bay Packers    741    561      37  0.567           1921
# 3      4     Miami Dolphins    443    345       4  0.562           1966
# 4      5   Baltimore Ravens    182    143       1  0.560           1996
#
#    Total Games  Conference         Stadium
# 0           894   NFC East    AT&T Stadium
# 1          1357  NFC North             NaN
# 2          1339  NFC North             NaN
# 3           792   AFC East             NaN
# 4           326  AFC North  Levi's Stadium

# %%
del nfl_frame["Stadium"]

# %%
nfl_frame
# Out:
#    Rank                Team   Won   Lost   Tied*   Pct.   First Season   \
# 0      1     Dallas Cowboys    510    378       6  0.574           1960
# 1      2      Chicago Bears    752    563      42  0.570           1920
# 2      3  Green Bay Packers    741    561      37  0.567           1921
# 3      4     Miami Dolphins    443    345       4  0.562           1966
# 4      5   Baltimore Ravens    182    143       1  0.560           1996
#
#    Total Games  Conference
# 0           894   NFC East
# 1          1357  NFC North
# 2          1339  NFC North
# 3           792   AFC East
# 4           326  AFC North

# %%
data = {"City": ["SF", "LA", "NYC"], "Population": [8.37e5, 3.88e6, 8.4e6]}

# %%
# Dataframe a partir de un diccionario
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
