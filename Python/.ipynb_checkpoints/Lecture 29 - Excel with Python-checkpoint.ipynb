# %%
import pandas as pd

# %%
xlsfile = pd.ExcelFile("../AnalyzeR_LatReach/Porsche/Moises/Base BR.xlsx")

# %%
dframe = xlsfile.parse("Resumen (2)")

# %%
dframe
# Out:
#     Unnamed: 0 Generación de Leads      Unnamed: 2  \
# 0          NaN                 NaN      Junio 2015
# 1          NaN                 NaN  YTD Junio 2015
# 2          NaN                 NaN      Junio 2014
# 3          NaN                 NaN        YTD 2014
# 4          NaN                 NaN            2014
# 5          NaN   Pruebas de manejo             NaN
# 6          NaN                 NaN      Junio 2015
# 7          NaN                 NaN  YTD Junio 2015
# 8          NaN                 NaN      Junio 2014
# 9          NaN                 NaN        YTD 2014
# 10         NaN                 NaN            2014
# 11         NaN        Desatendidos             NaN
# 12         NaN                 NaN      Junio 2015
# 13         NaN                 NaN  YTD Junio 2015
# 14         NaN                 NaN      Junio 2014
# 15         NaN                 NaN        YTD 2014
# 16         NaN                 NaN            2014
#
# ...
