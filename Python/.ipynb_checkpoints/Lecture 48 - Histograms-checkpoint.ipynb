# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  5.,  10.,   5.,  14.,  22.,  15.,  20.,   5.,   2.,   2.]),
#  array([-2.1065834 , -1.6473356 , -1.18808779, -0.72883999, -0.26959219,
#          0.18965562,  0.64890342,  1.10815122,  1.56739902,  2.02664683,
#          2.48589463]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

plt.hist(dataset2, color = 'indianred')
# Out:
# (array([  3.,   3.,  10.,  12.,  15.,  13.,   9.,   8.,   4.,   3.]),
#  array([-2.35140539, -1.89409654, -1.4367877 , -0.97947885, -0.52217001,
#         -0.06486117,  0.39244768,  0.84975652,  1.30706536,  1.76437421,
#          2.22168305]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, color = "indianred", alpha = 0.5, bins = 20)
plt.hist(dataset2, normed=True, alpha = 0.5, bins = 20)
# Out:
# (array([ 0.05466765,  0.1093353 ,  0.        ,  0.16400295,  0.1093353 ,
#          0.4373412 ,  0.16400295,  0.49200885,  0.38267355,  0.4373412 ,
#          0.27333825,  0.4373412 ,  0.27333825,  0.2186706 ,  0.27333825,
#          0.16400295,  0.2186706 ,  0.        ,  0.05466765,  0.1093353 ]),
#  array([-2.35140539, -2.12275096, -1.89409654, -1.66544212, -1.4367877 ,
#         -1.20813328, -0.97947885, -0.75082443, -0.52217001, -0.29351559,
#         -0.06486117,  0.16379325,  0.39244768,  0.6211021 ,  0.84975652,
#          1.07841094,  1.30706536,  1.53571978,  1.76437421,  1.99302863,
#          2.22168305]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1e5)
data2 = randn(1e5)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind = "hex")

# %%
sns.distplot(data1, hist = False, kde = True, rug = False)
sns.distplot(data2, hist = False, kde = True, rug = False, color = "red")
