# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import pandas.util.testing as tm; tm.N = 3

def unpivot(frame):
    N, K = frame.shape
    
    data = {"value": frame.values.ravel("F"),
            "variable": np.asarray(frame.columns).repeat(N),
            "date": np.tile(np.asarray(frame.index), K)}
    
    # Return DataFrame
    return DataFrame(data, columns = ["date", "variable", "value"])
    
# Set the DataFrame we'll be using
dframe = unpivot(tm.makeTimeDataFrame())

# %%
dframe
# Out:
#          date variable     value
# 0  2000-01-03        A  0.733509
# 1  2000-01-04        A  1.354590
# 2  2000-01-05        A  1.041973
# 3  2000-01-03        B -1.064426
# 4  2000-01-04        B -1.202948
# 5  2000-01-05        B  0.464036
# 6  2000-01-03        C  0.778246
# 7  2000-01-04        C  1.085932
# 8  2000-01-05        C -0.655295
# 9  2000-01-03        D  1.732481
# 10 2000-01-04        D  0.180834
# 11 2000-01-05        D -1.443601

# %%
dframe_piv = dframe.pivot("date", "variable", "value")
dframe_piv
# Out:
# variable           A         B         C         D
# date
# 2000-01-03  0.733509 -1.064426  0.778246  1.732481
# 2000-01-04  1.354590 -1.202948  1.085932  0.180834
# 2000-01-05  1.041973  0.464036 -0.655295 -1.443601
